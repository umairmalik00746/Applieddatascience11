# %% [markdown]
# # <strong>Italy Population</strong>: Comparision
# Timeline: 1955 - 2020

# %%
# Imporitng Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Importing Dataset
file = pd.read_excel("Italy_Population -1955-2020.xlsx")
# file = file[:5]
file
# Out:
#     Year   Population  Yearly % Change Yearly Change Migrants (net)  \
# 0   2020  6,04,61,826          -0.0015        -88249       1,48,943
# 1   2019  6,05,50,075          -0.0013        -77216       1,48,943
# 2   2018  6,06,27,291          -0.0008        -46410       1,48,943
# 3   2017  6,06,73,701           0.0002         10641       1,48,943
# 4   2016  6,06,63,060           0.0014         84566       1,48,943
# 5   2015  6,05,78,494           0.0042      2,50,653       3,27,474
# 6   2010  5,93,25,229           0.0036      2,08,803       2,10,190
# 7   2005  5,82,81,212           0.0055      3,17,807       3,32,869
# 8   2000  5,66,92,178          -0.0017        -96446       2,59,947
# 9   1995  5,71,74,408           0.0004         25234       1,23,065
# 10  1990  5,70,48,236           0.0004         22292       1,12,012
# 11  1985  5,69,36,774           0.0021      1,17,485       2,25,260
# 12  1980  5,63,49,349           0.0039      2,16,813       3,29,850
# ...

# %%
# Converting Strings to Integers

total_world_population = file['Migrants (net)'].str.replace(",", "").astype(np.int64)
total_italy_Population = file['Population'].str.replace(",", "").astype(np.int64)
# yearly_chaging = file['Yearly % Change'].astype(np.int64)
year = file.loc[:,"Year"]

# %%
# # Multiple Projections  
# plt.figure(figsize=(12, 5))
# # plt.plot(year, total_world_population, label="total_world_population")
# plt.plot(year, total_italy_Population, label="total_italy_Population")
# plt.title("Peple's Age VS Work Hour")
# plt.legend()
# plt.show()

# plt.figure(figsize= (12,3))
# # plt.plot(year, yearly_chaging, color="blue", label="Yearly % Change")
# plt.plot(year, total_italy_Population,color = "red" , label="Population")
# plt.plot(year, total_world_population,color="green", label="World Population'")

# plt.grid(linewidth=1)
# plt.legend()

fig, ax1 = plt.subplots()
ax1.set_ylabel('Migrants (net)')
ax1.plot(year, total_world_population, color='green',label="Migrants (net)")
ax1.grid()
ax2 = ax1.twinx()  # join a second axis with the first graph we just made
ax2.set_ylabel('Population')
ax2.plot(year, total_italy_Population, color='red',label=" Population")
plt.title('Migrants Vs Population')
fig.legend()
plt.show()

# %%
x = total_world_population[:7]
y = file["Year"]
y = y[:7]
y


plt.pie(x, labels=y,autopct = '%.2f' )

# plot = plt.pie(subplots=True, figsize=(11, 6))

# plt.figsize=(11, 6)

plt.title('Migrants in different years')

plt.show()

# %%
plt.bar(file["Year"],total_world_population)
plt.xlabel('year')
plt.ylabel(total_world_population')
plt.title('total_world_population in different decades')

plt.show()
